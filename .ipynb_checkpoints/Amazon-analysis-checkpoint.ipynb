# %% [markdown]
# ### Step 1 Load data into data frame

# %%
import pandas as pd

# Load the CSV file into a new DataFrame
combined_df_2022 = pd.read_csv('year_2022.csv')

# %%
### Step 2 Pick week before Holiday

# %%
# Define the date range
start_date = '12-17-2022'
end_date = '12-25-2022'

# Filter the DataFrame for the date range
filtered_df_holiday = combined_df_2022[(combined_df_2022['date'] >= start_date) & (combined_df_2022['date'] <= end_date)]

# Print the shape of the filtered DataFrame
print(filtered_df_holiday.shape)
# Out:
# (59129, 8)

# %% [markdown]
# ### Step 3 Sort the data by dates

# %%
sorted_df_2022 = filtered_df_holiday.sort_values(by='date', ascending=False)

# %% [markdown]
# ### Step 4 Check the rating distribution

# %%
#Score Column evaluation
sorted_df_2022['rating'].value_counts().sort_index().plot(kind='bar', title='Rating reviews week of Chrismas 2022')
# Out:
# <Axes: title={'center': 'Rating reviews week of Chrismas 2022'}>

# %% [markdown]
# ### Step 5 Load nltk dependencies

# %%
#Load Dependencies
import nltk
from nltk import word_tokenize
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\savav\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\savav\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\savav\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\savav\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ### Step 6 Vader Sentiment Analyis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sentiment_analyizer_object = SentimentIntensityAnalyzer()

# %% [markdown]
# ### Step 7 For loop to run sentiment analysis and save in a new res dictiona

# %%
sorted_df_2022
# Out:
#          rating                                               text  \
# 806575      5.0  This product has been a life saver at my house...
# 252290      5.0                                    A good product.
# 934638      4.0  I have a husky so of course she learned how to...
# 2240569     4.0  This product was easy to mount and self servin...
# 934655      5.0  My doggie loves it so much. He plays with it e...
# ...         ...                                                ...
# 761293      5.0  Our pug surprisingly fit into a large. I was w...
# 761277      5.0                      I like everything about them.
# 761081      5.0  The leash is extremely long and I have an acti...
# 760727      1.0  This was tore apart in one day,<br />It’s a cu...
# 11          3.0  Worked great until my Boston was getting down ...
#
#                asin                timestamp parent_asin  \
# 806575   B0BLTL1JQV  2022-12-25 06:56:34.956  B0C4Y2TP9H
# 252290   B01N9QTLY1  2022-12-25 19:25:48.848  B01N9QTLY1
# 934638   B09YTM4PB5  2022-12-25 14:25:39.177  B0B76G87FG
# 2240569  B07JJ1R57B  2022-12-25 03:26:09.477  B07JJ1R57B
# 934655   B09YTM4PB5  2022-12-25 01:45:16.718  B0B76G87FG
# ...             ...                      ...         ...
# 761293   B07KQYVKF4  2022-12-17 16:25:16.656  B08NPSXC3Q
# 761277   B09TR49DQR  2022-12-17 23:09:30.885  B07JGJC9CV
# 761081   B07S3WNWRS  2022-12-17 18:25:27.534  B07RYMR7ST
# 760727   B00HSJFJOI  2022-12-17 01:40:15.123  B00HSJFJOI
# 11       B084SV3JR4  2022-12-17 19:33:31.875  B0BHTBS5RM
#
#                                                      title  \
# 806575   Crazy Furball Calming Chews for Dogs, Composur...
# 252290   Full Moon Chicken Nuggets Healthy All Natural ...
# 934638   MateeyLife Dog Puzzle Toys, Dog Treat Puzzle f...
# 2240569  Mini Dog Waste Station - Free 400 dog waste ba...
# 934655   MateeyLife Dog Puzzle Toys, Dog Treat Puzzle f...
# ...                                                    ...
# 761293   PETLOFT Dog Winter Jacket, Reflective Waterpro...
# 761277   SlowTon Dog Seat Belt, 2 in 1 Dog Car Leash Se...
# 761081   Nylon Training Dog Leash for Small Medium Larg...
# 760727   Ethical Pets Gigglers Chicken Dog Toy, 12-Inch...
# 11       PetSafe CozyUp Folding Dog Stairs - Pet Stairs...
#
#                     main_category        date
# 806575               Pet Supplies  12-25-2022
# 252290               Pet Supplies  12-25-2022
# 934638               Pet Supplies  12-25-2022
# 2240569  Tools & Home Improvement  12-25-2022
# 934655               Pet Supplies  12-25-2022
# ...                           ...         ...
# 761293               Pet Supplies  12-17-2022
# 761277               Pet Supplies  12-17-2022
# 761081               Pet Supplies  12-17-2022
# 760727               Pet Supplies  12-17-2022
# 11                   Pet Supplies  12-17-2022
#
# [59129 rows x 8 columns]

# %% [markdown]
# ### Step 8 For loop to run sentiment analysis and save in a new res dictionary

# %%
### Run the polarity score on the entire dataset

sorted_df_2022['text'] = sorted_df_2022['text'].astype(str)

res = {}
for i, row in tqdm(sorted_df_2022.iterrows(), total=len(sorted_df_2022)):
    text = row['text']
    #print(text)
    res[i] = sentiment_analyizer_object.polarity_scores(text)
# Out:
#   0%|          | 0/59129 [00:00<?, ?it/s]

# %% [markdown]
# ### Step 9 Save dictionary into a dataframe and print it out

# %%
vaders_christmas_2022 = pd.DataFrame(res).T
vaders_christmas_2022
# Out:
#            neg    neu    pos  compound
# 806575   0.119  0.736  0.146    0.4118
# 252290   0.000  0.256  0.744    0.4404
# 934638   0.136  0.699  0.165    0.1154
# 2240569  0.000  0.917  0.083    0.4404
# 934655   0.000  0.626  0.374    0.7152
# ...        ...    ...    ...       ...
# 761293   0.028  0.512  0.459    0.9761
# 761277   0.000  0.545  0.455    0.3612
# 761081   0.051  0.744  0.205    0.7650
# 760727   0.000  0.800  0.200    0.4588
# 11       0.141  0.653  0.206    0.3182
#
# [59129 rows x 4 columns]

# %% [markdown]
# ### Step 10 Merge the vader dataset with Neg/Neu/Pos compound fields with the original 2022 sorted data set

# %%
vaders_christmas_2022 = pd.DataFrame(res).T
merged_christmas_2022 = pd.merge(vaders_christmas_2022, sorted_df_2022, left_index=True, right_index=True)

# %%
merged_christmas_2022
# Out:
#            neg    neu    pos  compound  rating  \
# 806575   0.119  0.736  0.146    0.4118     5.0
# 252290   0.000  0.256  0.744    0.4404     5.0
# 934638   0.136  0.699  0.165    0.1154     4.0
# 2240569  0.000  0.917  0.083    0.4404     4.0
# 934655   0.000  0.626  0.374    0.7152     5.0
# ...        ...    ...    ...       ...     ...
# 761293   0.028  0.512  0.459    0.9761     5.0
# 761277   0.000  0.545  0.455    0.3612     5.0
# 761081   0.051  0.744  0.205    0.7650     5.0
# 760727   0.000  0.800  0.200    0.4588     1.0
# 11       0.141  0.653  0.206    0.3182     3.0
#
#                                                       text        asin  \
# 806575   This product has been a life saver at my house...  B0BLTL1JQV
# 252290                                     A good product.  B01N9QTLY1
# 934638   I have a husky so of course she learned how to...  B09YTM4PB5
# 2240569  This product was easy to mount and self servin...  B07JJ1R57B
# 934655   My doggie loves it so much. He plays with it e...  B09YTM4PB5
# ...                                                    ...         ...
# 761293   Our pug surprisingly fit into a large. I was w...  B07KQYVKF4
# 761277                       I like everything about them.  B09TR49DQR
# 761081   The leash is extremely long and I have an acti...  B07S3WNWRS
# 760727   This was tore apart in one day,<br />It’s a cu...  B00HSJFJOI
# 11       Worked great until my Boston was getting down ...  B084SV3JR4
#
#                        timestamp parent_asin  \
# 806575   2022-12-25 06:56:34.956  B0C4Y2TP9H
# 252290   2022-12-25 19:25:48.848  B01N9QTLY1
# 934638   2022-12-25 14:25:39.177  B0B76G87FG
# 2240569  2022-12-25 03:26:09.477  B07JJ1R57B
# 934655   2022-12-25 01:45:16.718  B0B76G87FG
# ...                          ...         ...
# 761293   2022-12-17 16:25:16.656  B08NPSXC3Q
# 761277   2022-12-17 23:09:30.885  B07JGJC9CV
# 761081   2022-12-17 18:25:27.534  B07RYMR7ST
# 760727   2022-12-17 01:40:15.123  B00HSJFJOI
# 11       2022-12-17 19:33:31.875  B0BHTBS5RM
#
#                                                      title  \
# 806575   Crazy Furball Calming Chews for Dogs, Composur...
# 252290   Full Moon Chicken Nuggets Healthy All Natural ...
# 934638   MateeyLife Dog Puzzle Toys, Dog Treat Puzzle f...
# 2240569  Mini Dog Waste Station - Free 400 dog waste ba...
# 934655   MateeyLife Dog Puzzle Toys, Dog Treat Puzzle f...
# ...                                                    ...
# 761293   PETLOFT Dog Winter Jacket, Reflective Waterpro...
# 761277   SlowTon Dog Seat Belt, 2 in 1 Dog Car Leash Se...
# 761081   Nylon Training Dog Leash for Small Medium Larg...
# 760727   Ethical Pets Gigglers Chicken Dog Toy, 12-Inch...
# 11       PetSafe CozyUp Folding Dog Stairs - Pet Stairs...
#
#                     main_category        date
# 806575               Pet Supplies  12-25-2022
# 252290               Pet Supplies  12-25-2022
# 934638               Pet Supplies  12-25-2022
# 2240569  Tools & Home Improvement  12-25-2022
# 934655               Pet Supplies  12-25-2022
# ...                           ...         ...
# 761293               Pet Supplies  12-17-2022
# 761277               Pet Supplies  12-17-2022
# 761081               Pet Supplies  12-17-2022
# 760727               Pet Supplies  12-17-2022
# 11                   Pet Supplies  12-17-2022
#
# [59129 rows x 12 columns]

# %% [markdown]
# ### Step 11 Plot vader compound score vs the rating

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.barplot(data=merged_christmas_2022, x='rating', y='compound')
ax.set_title('Compound score by Amazon star Review')
plt.show()

# %%
### Step 12 Compare vader score with positive neutral or negative scores

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
sns.barplot(data=merged_christmas_2022, x='rating', y='pos', ax =axs[0])
sns.barplot(data=merged_christmas_2022, x='rating', y='neu', ax =axs[1])
sns.barplot(data=merged_christmas_2022, x='rating', y='neg', ax =axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()
